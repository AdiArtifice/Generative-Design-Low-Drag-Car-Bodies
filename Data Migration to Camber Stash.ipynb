# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. Zip the F_S_WWC_WM folder
import os

folder_path = "/content/drive/MyDrive/My Projects/EV Cars Mesh Dataset/Main Project Resource/3D meshes of EV cars/F_S_WWC_WM"

if not os.path.exists(folder_path):
    print(f"Error: The path '{folder_path}' does not exist.")
    print("Please verify your Google Drive mount and folder structure.")
else:
    print(f"Target folder verified at: {folder_path}")
    print("Zipping the folder to /content/F_S_WWC_WM.zip (this will take a few minutes)...")
    # Zip quietly (-q) to avoid printing thousands of lines
    # !zip -q -r /content/F_S_WWC_WM.zip "{folder_path}"
    print("Zipping complete! Check file size:")
    # !ls -lh /content/F_S_WWC_WM.zip
# Out:
# Target folder verified at: /content/drive/MyDrive/My Projects/EV Cars Mesh Dataset/Main Project Resource/3D meshes of EV cars/F_S_WWC_WM
# Zipping the folder to /content/F_S_WWC_WM.zip (this will take a few minutes)...
# Zipping complete! Check file size:
# -rw-r--r-- 1 root root 22G Jun  6 12:47 /content/F_S_WWC_WM.zip

# %%
# 3. Setup Camber CLI and Upload to Stash (Organized Structure)
import os

# Install Camber CLI in the Colab container
# !curl -sL https://cli.cambercloud.com/install-v2.sh | bash

# Configure your Camber API Key
os.environ["CAMBER_API_KEY"] = "040b1ec4afff843bddae8cc4665d5aa22007f003"

# Upload the zipped dataset to an organized directory in Camber Stash
print("Uploading F_S_WWC_WM.zip to Camber Stash (drivaer_dataset/raw_stl/)...")
# !/root/.camber/bin/camber stash cp /content/F_S_WWC_WM.zip stash://adityabehera28502187/drivaer_dataset/raw_stl/F_S_WWC_WM.zip
print("Upload complete!")
# Out:
# Installing camber version 1.0.29 for Linux_x86_64...
# ...
# Extracting archive...
# Installing binary to /root/.camber/bin...
# Added /root/.camber/bin to PATH in .bashrc
# Installation complete!
# Please restart your shell or run:
#     source ~/.bashrc
# You can now use 'camber' command.
# Uploading F_S_WWC_WM.zip to Camber Stash (drivaer_dataset/raw_stl/)...
# Perform copying /content/F_S_WWC_WM.zip to stash://adityabehera28502187/drivaer_dataset/raw_stl/F_S_WWC_WM.zip
# user/9e08ea45-e1ff-4739-a7ff-eaaf25817c3c/drivaer_dataset/raw_stl/F_S_WWC_WM.zip
# Uploading /content/F_S_WWC_WM.zip: 100.00% (21.3GB/21.3GB) 101.61 MB/s
# Uploading /content/F_S_WWC_WM.zip: 100.00% (21.3GB/21.3GB) 0.00 B/sUpload complete!

# %%
# 1. Check the actual size of the zip file so far
# !ls -lh /content/F_S_WWC_WM.zip

# 2. Check the overall disk space partition sizes in Colab
# !df -h /content
# Out:
# -rw-r--r-- 1 root root 22G Jun  6 12:47 /content/F_S_WWC_WM.zip
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   55G   54G  51% /
